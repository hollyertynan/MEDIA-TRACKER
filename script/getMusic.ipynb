# %%
import requests
import os
res = requests.get("http://www.popvortex.com/music/charts/top-100-albums.php")

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(res.text, 'html.parser')

# %%
images = soup.select(".cover-art img")
print(len(images))
print(images)
# Out:
# 100
# [<img alt="Encanto (Original Motion Picture Soundtrack) - Lin-Manuel Miranda, Germaine Franco, Stephanie Beatriz, Olga Merediz &amp;amp; Jessica Darrow Cover Art" class="cover-image b-lazy" data-pin-description="Encanto (Original Motion Picture Soundtrack) - Lin-Manuel Miranda, Germaine Franco, Stephanie Beatriz, Olga Merediz &amp; Jessica Darrow" data-pin-media="https://is4-ssl.mzstatic.com/image/thumb/Music126/v4/94/4d/9a/944d9a8d-0549-f537-5706-5b083bd84a7d/21UM1IM38949.rgb.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is4-ssl.mzstatic.com/image/thumb/Music126/v4/94/4d/9a/944d9a8d-0549-f537-5706-5b083bd84a7d/21UM1IM38949.rgb.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="Texas Moon - EP - Khruangbin &amp;amp; Leon Bridges Cover Art" class="cover-image b-lazy" data-pin-description="Texas Moon - EP - Khruangbin &amp; Leon Bridges" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/56/7b/7b/567b7bb8-70b8-0205-9473-6af9de2b523a/28599.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/56/7b/7b/567b7bb8-70b8-0205-9473-6af9de2b523a/28599.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="Sing 2 (Original Motion Picture Soundtrack) - Various Artists Cover Art" class="cover-image b-lazy" data-pin-description="Sing 2 (Original Motion Picture Soundtrack) - Various Artists" data-pin-media="https://is5-ssl.mzstatic.com/image/thumb/Music126/v4/c2/d2/6d/c2d26dcf-7e1b-ed4c-f598-f8dcb42b0f75/21UM1IM35664.rgb.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is5-ssl.mzstatic.com/image/thumb/Music126/v4/c2/d2/6d/c2d26dcf-7e1b-ed4c-f598-f8dcb42b0f75/21UM1IM35664.rgb.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="222 - Topher Cover Art" class="cover-image b-lazy" data-pin-description="222 - Topher" data-pin-media="https://is2-ssl.mzstatic.com/image/thumb/Music116/v4/cb/60/84/cb6084c8-519a-072a-b896-53abcccbbbc1/artwork.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is2-ssl.mzstatic.com/image/thumb/Music116/v4/cb/60/84/cb6084c8-519a-072a-b896-53abcccbbbc1/artwork.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="Good Morning Gorgeous - Mary J. Blige Cover Art" class="cover-image b-lazy" data-pin-description="Good Morning Gorgeous - Mary J. Blige" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/ff/7d/1e/ff7d1e81-a51b-09d8-a010-4350622cd9bb/810043687966.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/ff/7d/1e/ff7d1e81-a51b-09d8-a010-4350622cd9bb/810043687966.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="Marry Me (Original Motion Picture Soundtrack) - Jennifer Lopez &amp;amp; Maluma Cover Art" class="cover-image b-lazy" data-pin-description="Marry Me (Original Motion Picture Soundtrack) - Jennifer Lopez &amp; Maluma" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/79/52/50/795250ae-d325-f883-49b2-536b53bc3f44/886449094684.jpg/1200x1200bb.png" data-pin-url="http://www.popvortex.com/music/charts/top-100-albums.php" data-src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/79/52/50/795250ae-d325-f883-49b2-536b53bc3f44/886449094684.jpg/200x200bb.png" height="200" src="/images/blank-cover.gif" width="200"/>, <img alt="YOUNG-LUV.COM - EP - STAYC Cover Art" class="cover-image b-lazy" data-pin-description="YOUNG-LUV.COM - EP - STAYC" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/e7/37/29/e73729f2-ec82-295d-40d0-3025b9f251d8/cover_KM0014771_1.jpg/1200x1200bb.png" data-pin-url="http://w ...

# %%
image_number = 0
for i in images:
    link = i['data-pin-media']
    print(link)
        
    image_link = requests.get(link)
    
    f = open('albums/myImage' + str(image_number) + '.png', 'wb')
    image_number = image_number + 1
    f.write(image_link.content)
    f.close()
    if image_number > 9:
        break

print(str(image_number) + ' out of ' + str(len(images)) + ' were saved successfully')
# Out:
# https://is4-ssl.mzstatic.com/image/thumb/Music126/v4/94/4d/9a/944d9a8d-0549-f537-5706-5b083bd84a7d/21UM1IM38949.rgb.jpg/1200x1200bb.png
# https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/56/7b/7b/567b7bb8-70b8-0205-9473-6af9de2b523a/28599.jpg/1200x1200bb.png
# https://is5-ssl.mzstatic.com/image/thumb/Music126/v4/c2/d2/6d/c2d26dcf-7e1b-ed4c-f598-f8dcb42b0f75/21UM1IM35664.rgb.jpg/1200x1200bb.png
# https://is2-ssl.mzstatic.com/image/thumb/Music116/v4/cb/60/84/cb6084c8-519a-072a-b896-53abcccbbbc1/artwork.jpg/1200x1200bb.png
# https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/ff/7d/1e/ff7d1e81-a51b-09d8-a010-4350622cd9bb/810043687966.jpg/1200x1200bb.png
# https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/79/52/50/795250ae-d325-f883-49b2-536b53bc3f44/886449094684.jpg/1200x1200bb.png
# https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/e7/37/29/e73729f2-ec82-295d-40d0-3025b9f251d8/cover_KM0014771_1.jpg/1200x1200bb.png
# https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/73/6d/7c/736d7cfb-c79d-c9a9-4170-5e71d008dea1/886449666430.jpg/1200x1200bb.png
# https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/10/a2/39/10a239bc-0f25-69d2-52df-b1fe755dcf19/20UM1IM03632.rgb.jpg/1200x1200bb.png
# https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/c1/38/08/c13808c6-5d58-71e0-e28f-4b777740d4c4/8804775250750_Cover.jpg/1200x1200bb.png
# 10 out of 100 were saved successfully
